# %% [markdown]
# # Experiment and document metrics for non-heuristic planning solution searches

# %% [markdown]
#
#
# |Problem 1|Breadth First Search    |     Depth First Graph Search |    Greedy Best First Graph Search |
#       |--------|------------|------------|-|
#       |Plan Length|6|12|6|
#       |Time(s)|0.085|0.017|0.0198|
#       |Expansions|43|12|7|
#       |Goal Tests|56|13|9|
#       |New Nodes|180|48|28|
#       |Optimal|Yes|No|Yes|
#
# |Problem 2|Breadth First Search    |     Depth First Graph Search |    Greedy Best First Graph Search |
#       |--------|------------|------------|-|
#       |Plan Length|9|346|9|
#       |Time(s)|17.56|2.85|2.62|
#       |Expansions|3401|350|550|
#       |Goal Tests|4672|351|552|
#       |New Nodes|31049|3142|4950|
#       |Optimal|Yes|No|Yes|
#
# |Problem 3|Breadth First Search    |     Depth First Graph Search |    Greedy Best First Graph Search |
#       |--------|------------|------------|-|
#       |Plan Length|12|3335|22|
#       |Time(s)|89.24|106.26|23.51|
#       |Expansions|14491|3491|4031|
#       |Goal Tests|17947|3492|4033|
#       |New Nodes|128184|29332|35794|
#       |Optimal|Yes|No|Yes|

# %%
from run_search import main

# %% [markdown]
# ## Planning Problem 1
#
# The metrics for Planning Problem 1 using Breadth First Search, Depth First Graph Search and Greedy Best First Graph Search are below

# %%
p_choices = [1]
s_choices = [1,3,7]
main(p_choices, s_choices)
# Out:
# Solving Air Cargo Problem 1 using breadth_first_search...
#
# Expansions   Goal Tests   New Nodes
#     43          56         180
#
# Plan length: 6  Time elapsed in seconds: 0.08519672500551678
# Load(C2, P2, JFK)
# Load(C1, P1, SFO)
# Fly(P2, JFK, SFO)
# Unload(C2, P2, SFO)
# Fly(P1, SFO, JFK)
# Unload(C1, P1, JFK)
#
#
# Solving Air Cargo Problem 1 using depth_first_graph_search...
#
# Expansions   Goal Tests   New Nodes
#     12          13          48
#
# Plan length: 12  Time elapsed in seconds: 0.01728222699603066
# Fly(P1, SFO, JFK)
# Fly(P2, JFK, SFO)
# Load(C1, P2, SFO)
# Fly(P2, SFO, JFK)
# Fly(P1, JFK, SFO)
# Unload(C1, P2, JFK)
# Fly(P2, JFK, SFO)
# Fly(P1, SFO, JFK)
# Load(C2, P1, JFK)
# Fly(P2, SFO, JFK)
# Fly(P1, JFK, SFO)
# Unload(C2, P1, SFO)
#
#
# Solving Air Cargo Problem 1 using greedy_best_first_graph_search with h_1...
#
# Expansions   Goal Tests   New Nodes
#     7           9           28
#
# Plan length: 6  Time elapsed in seconds: 0.019834020000416785
# ...

# %% [markdown]
# ## Planning Problem 2
#
# The metrics for Planning Problem 2 using Breadth First Search, Depth First Graph Search and Greedy Best First Graph Search are below

# %%
p_choices = [2]
s_choices = [1,3,7]
main(p_choices, s_choices)
# Out:
# Solving Air Cargo Problem 2 using breadth_first_search...
#
# Expansions   Goal Tests   New Nodes
#    3401        4672       31049
#
# Plan length: 9  Time elapsed in seconds: 17.56106509699748
# Load(C3, P3, ATL)
# Load(C2, P2, JFK)
# Load(C1, P1, SFO)
# Fly(P3, ATL, SFO)
# Unload(C3, P3, SFO)
# Fly(P2, JFK, SFO)
# Unload(C2, P2, SFO)
# Fly(P1, SFO, JFK)
# Unload(C1, P1, JFK)
#
#
# Solving Air Cargo Problem 2 using depth_first_graph_search...
#
# Expansions   Goal Tests   New Nodes
#    350         351         3142
#
# Plan length: 346  Time elapsed in seconds: 2.8466223389987135
# Fly(P1, SFO, JFK)
# Fly(P2, JFK, SFO)
# Fly(P1, JFK, ATL)
# Fly(P2, SFO, ATL)
# Fly(P3, ATL, SFO)
# Fly(P1, ATL, SFO)
# Fly(P3, SFO, JFK)
# Fly(P1, SFO, JFK)
# Load(C2, P3, JFK)
# Fly(P3, JFK, SFO)
# Fly(P1, JFK, SFO)
# Fly(P3, SFO, ATL)
# Fly(P1, SFO, ATL)
# Fly(P2, ATL, SFO)
# Fly(P3, ATL, SFO)
# Fly(P2, SFO, JFK)
# Fly(P3, SFO, JFK)
# Fly(P1, ATL, SFO)
# Fly(P2, JFK, SFO)
# Load(C1, P2, SFO)
# ...

# %% [markdown]
# ## Planning Problem 3
#
# The metrics for Planning Problem 3 using Breadth First Search, Depth First Graph Search and Greedy Best First Graph Search are below

# %%
p_choices = [3]
s_choices = [1,3,7]
main(p_choices, s_choices)
# Out:
# Solving Air Cargo Problem 3 using breadth_first_search...
#
# Expansions   Goal Tests   New Nodes
#   14491       17947       128184
#
# Plan length: 12  Time elapsed in seconds: 89.24018592700304
# Load(C2, P2, JFK)
# Load(C1, P1, SFO)
# Fly(P2, JFK, ORD)
# Load(C4, P2, ORD)
# Fly(P2, ORD, SFO)
# Unload(C2, P2, SFO)
# Unload(C4, P2, SFO)
# Fly(P1, SFO, ATL)
# Load(C3, P1, ATL)
# Fly(P1, ATL, JFK)
# Unload(C1, P1, JFK)
# Unload(C3, P1, JFK)
#
#
# Solving Air Cargo Problem 3 using depth_first_graph_search...
#
# Expansions   Goal Tests   New Nodes
#    3491        3492       29322
#
# Plan length: 3335  Time elapsed in seconds: 106.25701307199779
# Fly(P1, SFO, ORD)
# Fly(P2, JFK, SFO)
# Fly(P1, ORD, JFK)
# Fly(P2, SFO, ORD)
# Fly(P1, JFK, ATL)
# Fly(P2, ORD, ATL)
# Load(C3, P2, ATL)
# Fly(P2, ATL, SFO)
# Fly(P1, ATL, SFO)
# Fly(P2, SFO, ORD)
# Fly(P1, SFO, ORD)
# Fly(P2, ORD, JFK)
# Fly(P1, ORD, JFK)
# Unload(C3, P2, JFK)
# Fly(P2, JFK, SFO)
# Fly(P1, JFK, SFO)
# Fly(P2, SFO, ORD)
# ...

# %%
p_choices = [1]
s_choices = [8,9,10]
main(p_choices, s_choices)
# Out:
# Solving Air Cargo Problem 1 using astar_search with h_1...
#
# Expansions   Goal Tests   New Nodes
#     55          57         224
#
# Plan length: 6  Time elapsed in seconds: 0.11312124400137691
# Load(C1, P1, SFO)
# Load(C2, P2, JFK)
# Fly(P1, SFO, JFK)
# Fly(P2, JFK, SFO)
# Unload(C1, P1, JFK)
# Unload(C2, P2, SFO)
#
#
# Solving Air Cargo Problem 1 using astar_search with h_ignore_preconditions...
#
# Expansions   Goal Tests   New Nodes
#     41          43         170
#
# Plan length: 6  Time elapsed in seconds: 0.07425256400165381
# Load(C1, P1, SFO)
# Fly(P1, SFO, JFK)
# Unload(C1, P1, JFK)
# Load(C2, P2, JFK)
# Fly(P2, JFK, SFO)
# Unload(C2, P2, SFO)
#
#
# Solving Air Cargo Problem 1 using astar_search with h_pg_levelsum...
#
# Expansions   Goal Tests   New Nodes
#     32          34         138
#
# Plan length: 6  Time elapsed in seconds: 2.4891117379956995
# Load(C1, P1, SFO)
# Fly(P1, SFO, JFK)
# Unload(C1, P1, JFK)
# Load(C2, P2, JFK)
# Fly(P2, JFK, SFO)
# ...

# %%
p_choices = [2]
s_choices = [8,9,10]
main(p_choices, s_choices)
# Out:
# Solving Air Cargo Problem 2 using astar_search with h_1...
#
# Expansions   Goal Tests   New Nodes
#    4761        4763       43206
#
# Plan length: 9  Time elapsed in seconds: 26.634657627997512
# Load(C1, P1, SFO)
# Load(C2, P2, JFK)
# Load(C3, P3, ATL)
# Fly(P1, SFO, JFK)
# Fly(P2, JFK, SFO)
# Fly(P3, ATL, SFO)
# Unload(C3, P3, SFO)
# Unload(C2, P2, SFO)
# Unload(C1, P1, JFK)
#
#
# Solving Air Cargo Problem 2 using astar_search with h_ignore_preconditions...
#
# Expansions   Goal Tests   New Nodes
#    1450        1452       13303
#
# Plan length: 9  Time elapsed in seconds: 8.946359207999194
# Load(C3, P3, ATL)
# Fly(P3, ATL, SFO)
# Unload(C3, P3, SFO)
# Load(C2, P2, JFK)
# Fly(P2, JFK, SFO)
# Unload(C2, P2, SFO)
# Load(C1, P1, SFO)
# Fly(P1, SFO, JFK)
# Unload(C1, P1, JFK)
#
#
# Solving Air Cargo Problem 2 using astar_search with h_pg_levelsum...
#
# Expansions   Goal Tests   New Nodes
#    168         170         1618
#
# ...

# %%
p_choices = [3]
s_choices = [8,9,10]
main(p_choices, s_choices)
# Out:
# Solving Air Cargo Problem 3 using astar_search with h_1...
#
# Expansions   Goal Tests   New Nodes
#   17783       17785       155920
#
# Plan length: 12  Time elapsed in seconds: 117.54251131499768
# Load(C1, P1, SFO)
# Load(C2, P2, JFK)
# Fly(P1, SFO, ATL)
# Load(C3, P1, ATL)
# Fly(P2, JFK, ORD)
# Load(C4, P2, ORD)
# Fly(P1, ATL, JFK)
# Fly(P2, ORD, SFO)
# Unload(C4, P2, SFO)
# Unload(C3, P1, JFK)
# Unload(C2, P2, SFO)
# Unload(C1, P1, JFK)
#
#
# Solving Air Cargo Problem 3 using astar_search with h_ignore_preconditions...
#
# Expansions   Goal Tests   New Nodes
#    5003        5005       44586
#
# Plan length: 12  Time elapsed in seconds: 36.719345952995354
# Load(C2, P2, JFK)
# Fly(P2, JFK, ORD)
# Load(C4, P2, ORD)
# Fly(P2, ORD, SFO)
# Unload(C4, P2, SFO)
# Load(C1, P1, SFO)
# Fly(P1, SFO, ATL)
# Load(C3, P1, ATL)
# Fly(P1, ATL, JFK)
# Unload(C3, P1, JFK)
# Unload(C2, P2, SFO)
# Unload(C1, P1, JFK)
#
#
# Solving Air Cargo Problem 3 using astar_search with h_pg_levelsum...
#
# ...
